# %%
'''import cgitb
cgitb.enable()

print ("Content-Type: text/plain;charset=utf-8")
print()

print ("Hello World!")
'''

file=open('terriblytinytales.txt','r')
d = dict() 
for line in file: 
     
    line = line.strip() 
  
    line = line.lower() 
   
    words = line.split(" ") 
  
    
    for word in words: 
       
        if word in d: 
           
            d[word] = d[word] + 1
        else: 
            
            d[word] = 1
 
for key in list(d.keys()): 
    print(key, ":", d[key])
# Out:
# 1. : 1
# who : 3
# are : 3
# you? : 2
#  : 53
# we're : 1
# terribly : 6
# tiny : 6
# tales : 2
# â€“ : 4
# one : 3
# of : 13
# the : 15
# worldâ€™s : 1
# most : 1
# celebrated : 1
# social : 3
# storytelling : 2
# platforms. : 2
# we : 7
# bring : 1
# together : 2
# a : 24
# diverse : 1
# pool : 1
# fantastic : 1
# writers : 3
# to : 23
# create : 2
# really : 1
# short : 2
# stories : 1
# for : 11
# community : 3
# over : 1
# 20 : 1
# million : 1
# readers, : 1
# every : 1
# day. : 1
# 2. : 1
# where : 8
# can : 18
# i : 27
# find : 6
# ttt : 5
# on : 11
# media? : 1
# you : 18
# us : 12
# facebook : 1
# (fb.com/terriblytinytales), : 1
# instagram : 1
# (@ttt_official), : 1
# twitter : 1
# (@terriblytiny), : 1
# and : 16
# youtube : 1
# (youtube.com/terriblytinytalkies) : 1
# 3. : 1
# read : 2
# all : 7
# your : 9
# stories? : 1
# / : 1
# want : 3
# tales; : 1
# them? : 1
# published : 1
# be : 5
# found : 1
# across : 3
# our : 10
# media : 1
# 4. : 1
# how : 7
# do : 10
# ...

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')

def homepage():
    return render_template("assignment.html")


if __name__== "__main__":
    app.run()
